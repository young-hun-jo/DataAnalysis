# %% [markdown]
# # . 씨네21 1년 전 영화정보 분석
#
# * 데이터 수집(1위~100위)
#
#     - POST방식 이용
#     - 메인 페이지의 영화 랭킹, 이름 크롤링
#     - 해당 영화 링크 접속해 영화 세부 정보 크롤링
#     - pymongo DB에 알맞은 dictionary 데이터 형태로 전처리
#     - value가 여러개인 값들은 list에 추가
#
#
# * 데이터 저장
#
#     - pymongo 연결, DB 생성, Collection 생성
#     - insert_many를 이용해 생성한 DB의 Collection에 입력
#
#
# * 데이터 분석
#
#     - pymongo SQL Query를 이용해 특정 조건의 데이터 추출

# %% [markdown]
# ``씨네 21 링크 : http://www.cine21.com/rank/boxoffice/domestic_content ``

# %% [markdown]
# ## 필요한 라이브러리 import

# %%
import requests
from bs4 import BeautifulSoup as bs
import re
import pymongo

# %% [markdown]
# ## pymongo와 연결, 데이터 넣을 DB, Collection

# %%
conn = pymongo.MongoClient()
cine_db = conn.cine
movie_info = cine_db.movie

# %% [markdown]
# ## 웹크롤링 코드 작성

# %%
url = "http://www.cine21.com/rank/boxoffice/domestic_content"
movies_info = []
header = {}
header['genre'] = 'all'
header['period'] = '2019-04-09'
for n in range(1,6):
    header['page'] = n
    res = requests.post(url, data=header)
    soup = bs(res.content, 'html.parser')

    movies = soup.select("ul.boxoffice_list li.boxoffice_li")
    for index, movie in enumerate(movies):
        name = movie.select_one('a > div.mov_name').text
        audience = movie.select_one('div.people_num').text
        audience = int(audience.split("|")[1].replace(",",''))
        # ranking도 문자열이므로 int형으로 바꿔주기
        ranking = int(movie.select_one('a span.grade.num1').text)
        link = movie.select_one('a')['href']
        link = f"http://www.cine21.com{link}"
        # 재귀적 접속 링크 요청 시작
        res = requests.get(link)
        soup = bs(res.content, 'html.parser')
        movie_details = {}
        year = soup.select_one("div.mov_info p.sub_info span:nth-child(1)").text
        country = soup.select_one("div.mov_info p.sub_info span:nth-child(2)").text
        proper_age = soup.select_one("div.mov_info p.sub_info span:nth-child(3)")
        if proper_age is None:
            proper_age = "연령대없음"
        else:
            proper_age = proper_age.text
        genre = soup.select_one("div.mov_info p:nth-child(4) span:nth-child(1)").text
        runtime = soup.select_one("div.mov_info p:nth-child(4) span:nth-child(2)")
        if runtime is None:
            runtime = "상영시간없음"
        else:
            runtime = runtime.text
            runtime = runtime.split(':')[1].strip()
        released_date = soup.select_one("div.mov_info p:nth-child(5) span")
        if released_date is None:
            released_date = "정보없음"
        else:
            released_date = released_date.text
            released_date = released_date.split(':')[1].strip()
        directors = soup.select("div.mov_info p:nth-child(6) a")
        directors_list = []
        for director in directors:
            director = director.text
            directors_list.append(director)
        # 인덱스 -1은 'more'을 나타내므로 마지막 인덱스를 제외한 나머지만 리스트로 담기
        actors = soup.select("div.mov_info p:nth-child(7) a")[:-1]
        actors_list = []
        for actor in actors:
            actor = actor.text
            actors_list.append(actor)

        cine_reviews = soup.select_one("ul.mov_rating li:nth-child(1) span")
        if cine_reviews is None:
            cine_reviews = "평점없음"
        else:
            cine_reviews = float(cine_reviews.text)
        people_reviews = soup.select_one("ul.mov_rating li:nth-child(2) span")
        if people_reviews is None:
            people_reviews = "평점없음"
        else:
            people_reviews = float(people_reviews.text)

        movie_details['영화이름'] = name
        movie_details['관객수'] = audience
        movie_details['순위'] = ranking
        movie_details['개봉연도'] = year
        movie_details['국가'] = country
        movie_details['관람적절연령'] = proper_age
        movie_details['장르'] = genre
        movie_details['상영시간'] = runtime
        movie_details['개봉날짜'] = released_date
        movie_details['감독'] = directors_list
        movie_details['출연배우'] = actors_list
        movie_details['씨네21평점'] = cine_reviews
        movie_details['네티즌평점'] = people_reviews

        movies_info.append(movie_details)

# %% [markdown]
# ## pymongo DB에 데이터 잘 들어가는지 확인
#
# - Robo 3T 앱을 이용해서 잘 들어갔는지 확인

# %%
movie_info.insert_one({'result':'mongo'})

# %%
movie_info.delete_many({})

# %% [markdown]
# ## pymongo DB에 크롤링한 데이터 입력

# %%
movie_info.insert_many(movies_info)

# %%
# 데이터가 잘 들어갔는지 간단하게 데이터 조회
docs = movie_info.find({})
for doc in docs:
    print(doc)
# Out:
# {'_id': ObjectId('5e8ecdf10287aaf25b95d824'), '영화이름': '어벤져스: 엔드게임', '관객수': 13779286, '순위': 1, '개봉연도': '2019', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '액션, SF', '상영시간': '181분', '개봉날짜': '2019-04-24', '감독': ['안소니 루소', '조 루소'], '출연배우': ['로버트 다우니 주니어', '크리스 에반스'], '씨네21평점': 7.17, '네티즌평점': 8.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d825'), '영화이름': '겨울왕국 2', '관객수': 13748486, '순위': 2, '개봉연도': '2019', '국가': '미국', '관람적절연령': '전체 관람가', '장르': '판타지, 코미디, 어드벤처, 애니메이션, 뮤지컬, 가족', '상영시간': '103분', '개봉날짜': '2019-11-21', '감독': ['크리스 벅', '제니퍼 리'], '출연배우': ['크리스틴 벨', '이디나 멘젤'], '씨네21평점': 6.25, '네티즌평점': 8.67}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d826'), '영화이름': '알라딘', '관객수': 12557831, '순위': 3, '개봉연도': '2019', '국가': '미국', '관람적절연령': '전체 관람가', '장르': '상영시간 : 128분', '상영시간': '상영시간없음', '개봉날짜': '2019-05-23', '감독': ['가이 리치'], '출연배우': ['메나 마수드', '윌 스미스'], '씨네21평점': 5.8, '네티즌평점': 8.43}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d827'), '영화이름': '기생충', '관객수': 10289709, '순위': 4, '개봉연도': '2019', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '드라마', '상영시간': '131분', '개봉날짜': '2019-05-30', '감독': ['봉준호'], '출연배우': ['송강호', '이선균'], '씨네21평점': 9.09, '네티즌평점': 9.14}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d828'), '영화이름': '엑시트', '관객수': 9437454, '순위': 5, '개봉연도': '2019', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '코미디, 액션', '상영시간': '103분', '개봉날짜': '2019-07-31', '감독': ['이상근'], '출연배우': ['조정석', '임윤아'], '씨네21평점': 7.17, '네티즌평점': 8.2}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d829'), '영화이름': '백두산', '관객수': 8253350, '순위': 6, '개봉연도': '2019', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '액션, 드라마', '상영시간': '128분', '개봉날짜': '2019-12-19', '감독': ['이해준', '김병서'], '출연배우': ['이병헌', '하정우'], '씨네21평점': 5.75, '네티즌평점': 5.22}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d82a'), '영화이름': '스파이더맨: 파 프롬 홈', '관객수': 8023586, '순위': 7, '개봉연도': '2019', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '상영시간 : 129분', '상영시간': '상영시간없음', '개봉날짜': '2019-07-02', '감독': ['존 와츠'], '출연배우': ['톰 홀랜드', '사무엘 L. 잭슨'], '씨네21평점': 6.5, '네티즌평점': 7.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d82b'), '영화이름': '조커', '관객수': 5255305, '순위': 8, '개봉연도': '2019', '국가': '미국', '관람적절연령': '15세 관람가', '장르': '스릴러', '상영시간': '123분', '개봉날짜': '2019-10-02', '감독': ['토드 필립스'], '출연배우': ['호아킨 피닉스', '재지 비츠'], '씨네21평점': 7.29, '네티즌평점': 8.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d82c'), '영화이름': '봉오동 전투', '관객수': 4793735, '순위': 9, '개봉연도': '2019', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '액션, 드라마', '상영시간': '135분', '개봉날짜': '2019-08-07', '감독': ['원신연'], '출연배우': ['유해진', '류준열'], '씨네21평점': 5.17, '네티즌평점': 6.75}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d82d'), '영화이름': '남산의 부장들', '관객수': 4748791, '순위': 10, '개봉연도': '2018', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '드라마', '상영시간': '114분', '개봉날짜': '2020-01-22', '감독': ['우민호'], '출연배우': ['이병헌', '이성민'], '씨네21평점': 7.0, '네티즌평점': 7.67}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d82e'), '영화이름': '라이온 킹', '관객수': 4743981, '순위': 11, '개봉연도': '2019', '국가': '미국', '관람적절연령': '전체 관람가', '장르': '어드벤처, 드라마, 가족', '상영시간': '118분', '개봉날짜': '2019-07-17', '감독': ['존 파브로'], '출연배우': ['도날드 글로버', '비욘세 놀즈'], '씨네21평점': 5.75, '네티즌평점': 7.75}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d82f'), '영화이름': '나쁜 녀석들: 더 무비', '관객수': 4558673, '순위': 12, '개봉연도': '2019', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '액션, 범죄', '상영시간': '115분', '개봉날짜': '2019-09-11', '감독': ['손용호'], '출연배우': ['마동석', '김상중'], '씨네21평점': 4.75, '네티즌평점': 6.6}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d830'), '영화이름': '82년생 김지영', '관객수': 3679469, '순위': 13, '개봉연도': '2019', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '드라마', '상영시간': '118분', '개봉날짜': '2019-10-23', '감독': ['김도영'], '출연배우': ['정유미', '공유'], '씨네21평점': 6.56, '네티즌평점': 8.38}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d831'), '영화이름': '분노의 질주: 홉스&쇼', '관객수': 3661614, '순위': 14, '개봉연도': '2019', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '액션', '상영시간': '135분', '개봉날짜': '2019-08-14', '감독': ['데이빗 레이치'], '출연배우': ['드웨인 존슨', '제이슨 스타뎀'], '씨네21평점': 6.0, '네티즌평점': 6.6}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d832'), '영화이름': '토이 스토리 4', '관객수': 3400646, '순위': 15, '개봉연도': '2019', '국가': '미국', '관람적절연령': '전체 관람가', '장르': '애니메이션', '상영시간': '100분', '개봉날짜': '2019-06-20', '감독': ['조시 쿨리'], '출연배우': ['톰 행크스', '팀 알렌'], '씨네21평점': 7.83, '네티즌평점': 8.67}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d833'), '영화이름': '악인전', '관객수': 3365161, '순위': 16, '개봉연도': '2018', '국가': '한국', '관람적절연령': '청소년 관람불가', '장르': '액션, 범죄', '상영시간': '110분', '개봉날짜': '2019-05-15', '감독': ['이원태'], '출연배우': ['마동석', '김무열'], '씨네21평점': 5.67, '네티즌평점': 6.57}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d834'), '영화이름': '시동', '관객수': 3317855, '순위': 17, '개봉연도': '2019', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '드라마', '상영시간': '102분', '개봉날짜': '2019-12-18', '감독': ['최정열'], '출연배우': ['마동석', '박정민'], '씨네21평점': 6.0, '네티즌평점': 7.33}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d835'), '영화이름': '가장 보통의 연애', '관객수': 2924376, '순위': 18, '개봉연도': '2019', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '멜로·로맨스', '상영시간': '109분', '개봉날짜': '2019-10-02', '감독': ['김한결'], '출연배우': ['김래원', '공효진'], '씨네21평점': 7.0, '네티즌평점': 7.57}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d836'), '영화이름': '블랙머니', '관객수': 2480413, '순위': 19, '개봉연도': '2019', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '범죄, 드라마', '상영시간': '113분', '개봉날짜': '2019-11-13', '감독': ['정지영'], '출연배우': ['조진웅', '이하늬'], '씨네21평점': 6.0, '네티즌평점': 7.17}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d837'), '영화이름': '터미네이터: 다크 페이트', '관객수': 2410405, '순위': 20, '개봉연도': '2019', '국가': '미국', '관람적절연령': '15세 관람가', '장르': '액션, SF', '상영시간': '128분', '개봉날짜': '2019-10-30', '감독': ['팀 밀러'], '출연배우': ['맥켄지 데이비스', '아놀드 슈워제네거'], '씨네21평점': 6.4, '네티즌평점': 8.29}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d838'), '영화이름': '히트맨', '관객수': 2402167, '순위': 21, '개봉연도': '2019', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '코미디, 액션', '상영시간': '110분', '개봉날짜': '2020-01-22', '감독': ['최원섭'], '출연배우': ['권상우', '정준호'], '씨네21평점': 5.5, '네티즌평점': 6.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d839'), '영화이름': '타짜: 원 아이드 잭', '관객수': 2225200, '순위': 22, '개봉연도': '2019', '국가': '한국', '관람적절연령': '청소년 관람불가', '장르': '범죄, 드라마', '상영시간': '139분', '개봉날짜': '2019-09-11', '감독': ['권오광'], '출연배우': ['박정민', '류승범'], '씨네21평점': 5.33, '네티즌평점': 6.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d83a'), '영화이름': '신의 한 수: 귀수편', '관객수': 2159733, '순위': 23, '개봉연도': '2019', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '액션, 범죄', '상영시간': '106분', '개봉날짜': '2019-11-07', '감독': ['리 건'], '출연배우': ['권상우', '김희원'], '씨네21평점': 5.0, '네티즌평점': 7.33}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d83b'), '영화이름': '천문: 하늘에 묻는다', '관객수': 2000746, '순위': 24, '개봉연도': '2018', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '드라마', '상영시간': '132분', '개봉날짜': '2019-12-26', '감독': ['허진호'], '출연배우': ['최민식', '한석규'], '씨네21평점': 6.83, '네티즌평점': 9.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d83c'), '영화이름': '변신', '관객수': 1805622, '순위': 25, '개봉연도': '2018', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '스릴러, 공포', '상영시간': '113분', '개봉날짜': '2019-08-21', '감독': ['김홍선'], '출연배우': ['배성우', '성동일'], '씨네21평점': 4.33, '네티즌평점': 4.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d83d'), '영화이름': '걸캅스', '관객수': 1629777, '순위': 26, '개봉연도': '2018', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '코미디, 액션', '상영시간': '107분', '개봉날짜': '2019-05-09', '감독': ['정다원'], '출연배우': ['라미란', '이성경'], '씨네21평점': 5.0, '네티즌평점': 4.83}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d83e'), '영화이름': '사자', '관객수': 1613631, '순위': 27, '개봉연도': '2019', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '판타지, 액션, 미스터리, 공포', '상영시간': '129분', '개봉날짜': '2019-07-31', '감독': ['김주환'], '출연배우': ['박서준', '안성기'], '씨네21평점': 4.8, '네티즌평점': 5.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d83f'), '영화이름': '닥터 두리틀', '관객수': 1606139, '순위': 28, '개봉연도': '2019', '국가': '미국', '관람적절연령': '전체 관람가', '장르': '판타지, 코미디, 가족', '상영시간': '101분', '개봉날짜': '2020-01-08', '감독': ['스티븐 개건'], '출연배우': ['로버트 다우니 주니어', '안토니오 반데라스'], '씨네21평점': 6.0, '네티즌평점': 7.2}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d840'), '영화이름': '정직한 후보', '관객수': 1527775, '순위': 29, '개봉연도': '2019', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '코미디', '상영시간': '105분', '개봉날짜': '2020-02-12', '감독': ['장유정'], '출연배우': ['라미란', '김무열'], '씨네21평점': 5.0, '네티즌평점': 4.2}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d841'), '영화이름': '나의 특별한 형제', '관객수': 1478466, '순위': 30, '개봉연도': '2018', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '코미디, 드라마', '상영시간': '114분', '개봉날짜': '2019-05-01', '감독': ['육상효'], '출연배우': ['신하균', '이광수'], '씨네21평점': 6.6, '네티즌평점': 7.6}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d842'), '영화이름': '말레피센트 2', '관객수': 1445143, '순위': 31, '개봉연도': '2019', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '판타지, 가족', '상영시간': '119분', '개봉날짜': '2019-10-17', '감독': ['요아킴 뢰닝'], '출연배우': ['안젤리나 졸리', '엘르 패닝'], '씨네21평점': 5.5, '네티즌평점': 7.8}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d843'), '영화이름': '포드 V 페라리', '관객수': 1367541, '순위': 32, '개봉연도': '2019', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '액션, 드라마', '상영시간': '152분', '개봉날짜': '2019-12-04', '감독': ['제임스 맨골드'], '출연배우': ['맷 데이먼', '크리스찬 베일'], '씨네21평점': 7.25, '네티즌평점': 8.86}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d844'), '영화이름': '클로젯', '관객수': 1264607, '순위': 33, '개봉연도': '2020', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '미스터리, 드라마', '상영시간': '98분', '개봉날짜': '2020-02-05', '감독': ['김광빈'], '출연배우': ['하정우', '김남길'], '씨네21평점': 5.4, '네티즌평점': 5.67}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d845'), '영화이름': '유열의 음악앨범', '관객수': 1245560, '순위': 34, '개봉연도': '2019', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '멜로·로맨스, 드라마', '상영시간': '122분', '개봉날짜': '2019-08-28', '감독': ['정지우'], '출연배우': ['김고은', '정해인'], '씨네21평점': 7.4, '네티즌평점': 8.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d846'), '영화이름': '퍼펙트맨', '관객수': 1240335, '순위': 35, '개봉연도': '2018', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '코미디, 드라마', '상영시간': '116분', '개봉날짜': '2019-10-02', '감독': ['용수'], '출연배우': ['설경구', '조진웅'], '씨네21평점': 5.0, '네티즌평점': 7.33}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d847'), '영화이름': '해치지않아', '관객수': 1224738, '순위': 36, '개봉연도': '2019', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '드라마', '상영시간': '117분', '개봉날짜': '2020-01-15', '감독': ['손재곤'], '출연배우': ['안재홍', '강소라'], '씨네21평점': 6.4, '네티즌평점': 6.71}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d848'), '영화이름': '힘을 내요, 미스터 리', '관객수': 1180720, '순위': 37, '개봉연도': '2018', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '코미디, 드라마', '상영시간': '111분', '개봉날짜': '2019-09-11', '감독': ['이계벽'], '출연배우': ['차승원', '엄채영'], '씨네21평점': 5.33, '네티즌평점': 5.6}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d849'), '영화이름': '장사리 : 잊혀진 영웅들', '관객수': 1120024, '순위': 38, '개봉연도': '2018', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '전쟁', '상영시간': '104분', '개봉날짜': '2019-09-25', '감독': ['곽경택', '김태훈'], '출연배우': ['김명민', '최민호'], '씨네21평점': 5.0, '네티즌평점': 7.33}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d84a'), '영화이름': '마이펫의 이중생활 2', '관객수': 1118590, '순위': 39, '개봉연도': '2019', '국가': '미국', '관람적절연령': '전체 관람가', '장르': '애니메이션', '상영시간': '85분', '개봉날짜': '2019-07-31', '감독': ['크리스 리노드'], '출연배우': ['패튼 오스왈트', '케빈 하트'], '씨네21평점': 5.0, '네티즌평점': 6.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d84b'), '영화이름': '롱 리브 더 킹: 목포 영웅', '관객수': 1094768, '순위': 40, '개봉연도': '2018', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '액션, 드라마', '상영시간': '118분', '개봉날짜': '2019-06-19', '감독': ['강윤성'], '출연배우': ['김래원', '원진아'], '씨네21평점': 4.67, '네티즌평점': 5.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d84c'), '영화이름': '쥬만지: 넥스트 레벨', '관객수': 1057427, '순위': 41, '개봉연도': '2019', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '어드벤처, 액션', '상영시간': '122분', '개봉날짜': '2019-12-11', '감독': ['제이크 캐스단'], '출연배우': ['드웨인 존슨', '잭 블랙'], '씨네21평점': 6.5, '네티즌평점': 6.6}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d84d'), '영화이름': '존 윅 3: 파라벨룸', '관객수': 1004326, '순위': 42, '개봉연도': '2019', '국가': '미국', '관람적절연령': '청소년 관람불가', '장르': '액션, 스릴러, 범죄', '상영시간': '131분', '개봉날짜': '2019-06-26', '감독': ['채드 스타헬스키'], '출연배우': ['키아누 리브스', '할리 베리'], '씨네21평점': 6.75, '네티즌평점': 7.25}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d84e'), '영화이름': '나랏말싸미', '관객수': 959129, '순위': 43, '개봉연도': '2018', '국가': '한국', '관람적절연령': '전체 관람가', '장르': '드라마', '상영시간': '110분', '개봉날짜': '2019-07-24', '감독': ['조철현'], '출연배우': ['송강호', '박해일'], '씨네21평점': 6.71, '네티즌평점': 7.2}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d84f'), '영화이름': '미드웨이', '관객수': 955656, '순위': 44, '개봉연도': '2019', '국가': '미국', '관람적절연령': '15세 관람가', '장르': '액션, 드라마', '상영시간': '136분', '개봉날짜': '2019-12-31', '감독': ['롤랜드 에머리히'], '출연배우': ['에드 스크레인', '패트릭 윌슨'], '씨네21평점': 5.33, '네티즌평점': 8.33}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d850'), '영화이름': '신비아파트 극장판 하늘도깨비 대 요르문간드', '관객수': 893742, '순위': 45, '개봉연도': '2019', '국가': '한국', '관람적절연령': '전체 관람가', '장르': '애니메이션', '상영시간': '97분', '개봉날짜': '2019-12-19', '감독': ['변영규'], '출연배우': ['김영은', '김채하'], '씨네21평점': 6.0, '네티즌평점': 10.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d851'), '영화이름': '엑스맨: 다크 피닉스', '관객수': 862743, '순위': 46, '개봉연도': '2018', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '상영시간 : 114분', '상영시간': '상영시간없음', '개봉날짜': '2019-06-05', '감독': ['사이먼 킨버그'], '출연배우': ['제임스 맥어보이', '마이클 패스벤더'], '씨네21평점': 5.75, '네티즌평점': 6.57}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d852'), '영화이름': '작은 아씨들', '관객수': 854871, '순위': 47, '개봉연도': '2019', '국가': '미국', '관람적절연령': '전체 관람가', '장르': '멜로·로맨스, 드라마', '상영시간': '135분', '개봉날짜': '2020-02-12', '감독': ['그레타 거윅'], '출연배우': ['엠마 왓슨', '시얼샤 로넌'], '씨네21평점': 8.0, '네티즌평점': 8.75}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d853'), '영화이름': '맨 인 블랙: 인터내셔널', '관객수': 852256, '순위': 48, '개봉연도': '2019', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '코미디, 액션, SF', '상영시간': '115분', '개봉날짜': '2019-06-12', '감독': ['F. 게리 그레이'], '출연배우': ['크리스 헴스워스', '테사 톰슨'], '씨네21평점': 4.33, '네티즌평점': 5.25}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d854'), '영화이름': '레드슈즈', '관객수': 817978, '순위': 49, '개봉연도': '2019', '국가': '한국', '관람적절연령': '전체 관람가', '장르': '애니메이션', '상영시간': '92분', '개봉날짜': '2019-07-25', '감독': ['홍성호'], '출연배우': ['클로이 모레츠', '샘 클라플린'], '씨네21평점': 6.0, '네티즌평점': '평점없음'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d855'), '영화이름': '나이브스 아웃', '관객수': 814655, '순위': 50, '개봉연도': '2019', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '추리, 스릴러, 미스터리', '상영시간': '130분', '개봉날짜': '2019-12-04', '감독': ['라이언 존슨'], '출연배우': ['다니엘 크레이그', '크리스 에반스'], '씨네21평점': 7.0, '네티즌평점': 8.8}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d856'), '영화이름': '생일', '관객수': 781476, '순위': 51, '개봉연도': '2018', '국가': '한국', '관람적절연령': '전체 관람가', '장르': '드라마', '상영시간': '120분', '개봉날짜': '2019-04-03', '감독': ['이종언'], '출연배우': ['설경구', '전도연'], '씨네21평점': 6.83, '네티즌평점': 8.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d857'), '영화이름': '뽀로로 극장판 보물섬 대모험', '관객수': 767251, '순위': 52, '개봉연도': '2019', '국가': '한국', '관람적절연령': '전체 관람가', '장르': '애니메이션', '상영시간': '79분', '개봉날짜': '2019-04-25', '감독': ['김현호', '윤창섭'], '출연배우': ['이선', '이미자'], '씨네21평점': 8.0, '네티즌평점': '평점없음'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d858'), '영화이름': '캣츠', '관객수': 757406, '순위': 53, '개봉연도': '2019', '국가': '영국,미국', '관람적절연령': '12세 관람가', '장르': '뮤지컬, 드라마', '상영시간': '109분', '개봉날짜': '2019-12-24', '감독': ['톰 후퍼'], '출연배우': ['제니퍼 허드슨', '테일러 스위프트'], '씨네21평점': 5.0, '네티즌평점': 6.33}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d859'), '영화이름': '1917', '관객수': 734166, '순위': 54, '개봉연도': '2019', '국가': '영국,미국', '관람적절연령': '15세 관람가', '장르': '전쟁, 드라마', '상영시간': '119분', '개봉날짜': '2020-02-19', '감독': ['샘 멘데스'], '출연배우': ['조지 맥케이', '딘-찰스 채프먼'], '씨네21평점': 7.33, '네티즌평점': 8.67}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d85a'), '영화이름': '명탐정 피카츄', '관객수': 686849, '순위': 55, '개봉연도': '2019', '국가': '일본,미국', '관람적절연령': '전체 관람가', '장르': '액션, 블록버스터', '상영시간': '104분', '개봉날짜': '2019-05-09', '감독': ['롭 레터맨'], '출연배우': ['라이언 레이놀즈', '저스티스 스미스'], '씨네21평점': 5.5, '네티즌평점': 6.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d85b'), '영화이름': '날씨의 아이', '관객수': 672880, '순위': 56, '개봉연도': '2019', '국가': '일본', '관람적절연령': '15세 관람가', '장르': '판타지, 애니메이션, 멜로·로맨스', '상영시간': '112분', '개봉날짜': '2019-10-30', '감독': ['신카이 마코토'], '출연배우': ['다이고 코타로', '모리 나나'], '씨네21평점': 6.5, '네티즌평점': 8.2}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d85c'), '영화이름': '나를 찾아줘', '관객수': 645132, '순위': 57, '개봉연도': '2019', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '스릴러', '상영시간': '108분', '개봉날짜': '2019-11-27', '감독': ['김승우'], '출연배우': ['이영애', '유재명'], '씨네21평점': 6.0, '네티즌평점': 7.75}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d85d'), '영화이름': '광대들: 풍문조작단', '관객수': 637809, '순위': 58, '개봉연도': '2019', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '드라마', '상영시간': '108분', '개봉날짜': '2019-08-21', '감독': ['김주호'], '출연배우': ['조진웅', '손현주'], '씨네21평점': 4.75, '네티즌평점': 6.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d85e'), '영화이름': '지푸라기라도 잡고 싶은 짐승들', '관객수': 620308, '순위': 59, '개봉연도': '2018', '국가': '한국', '관람적절연령': '청소년 관람불가', '장르': '스릴러, 범죄', '상영시간': '108분', '개봉날짜': '2020-02-19', '감독': ['김용훈'], '출연배우': ['전도연', '정우성'], '씨네21평점': 6.5, '네티즌평점': 6.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d85f'), '영화이름': '미스터 주: 사라진 VIP', '관객수': 602401, '순위': 60, '개봉연도': '2019', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '코미디, 드라마', '상영시간': '113분', '개봉날짜': '2020-01-22', '감독': ['김태윤'], '출연배우': ['이성민', '김서형'], '씨네21평점': 4.5, '네티즌평점': 5.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d860'), '영화이름': '그것: 두 번째 이야기', '관객수': 591238, '순위': 61, '개봉연도': '2019', '국가': '미국', '관람적절연령': '15세 관람가', '장르': '스릴러', '상영시간': '169분', '개봉날짜': '2019-09-04', '감독': ['안드레스 무시에티'], '출연배우': ['빌 스카스가드', '제임스 맥어보이'], '씨네21평점': 7.0, '네티즌평점': 7.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d861'), '영화이름': '극장판 헬로카봇 : 달나라를 구해줘!', '관객수': 590261, '순위': 62, '개봉연도': '2019', '국가': '한국', '관람적절연령': '전체 관람가', '장르': '애니메이션', '상영시간': '76분', '개봉날짜': '2019-09-04', '감독': ['최신규', '김진철'], '출연배우': ['이지현', '김용준'], '씨네21평점': '평점없음', '네티즌평점': '평점없음'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d862'), '영화이름': '인비저블맨', '관객수': 548819, '순위': 63, '개봉연도': '2020', '국가': '미국', '관람적절연령': '15세 관람가', '장르': '공포', '상영시간': '124분', '개봉날짜': '2020-02-26', '감독': ['리 워넬'], '출연배우': ['엘리자베스 모스', '올리버 잭슨 코헨'], '씨네21평점': 7.0, '네티즌평점': 6.75}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d863'), '영화이름': '나쁜 녀석들: 포에버', '관객수': 547820, '순위': 64, '개봉연도': '2020', '국가': '미국', '관람적절연령': '청소년 관람불가', '장르': '액션, 블록버스터', '상영시간': '124분', '개봉날짜': '2020-01-15', '감독': ['아딜 엘 아르비', '빌랄 팔라'], '출연배우': ['윌 스미스', '마틴 로렌스'], '씨네21평점': 6.0, '네티즌평점': 7.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d864'), '영화이름': '양자물리학', '관객수': 544988, '순위': 65, '개봉연도': '2019', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '범죄', '상영시간': '119분', '개봉날짜': '2019-09-25', '감독': ['이성태'], '출연배우': ['박해수', '서예지'], '씨네21평점': 4.5, '네티즌평점': 4.8}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d865'), '영화이름': '애드 아스트라', '관객수': 512309, '순위': 66, '개봉연도': '2019', '국가': '브라질,미국', '관람적절연령': '12세 관람가', '장르': '스릴러, SF', '상영시간': '123분', '개봉날짜': '2019-09-19', '감독': ['제임스 그레이'], '출연배우': ['브래드 피트', '토미 리 존스'], '씨네21평점': 7.2, '네티즌평점': 8.13}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d866'), '영화이름': '스타워즈: 라이즈 오브 스카이워커', '관객수': 507549, '순위': 67, '개봉연도': '2019', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '판타지, 액션, SF', '상영시간': '141분', '개봉날짜': '2020-01-08', '감독': ['J.J. 에이브럼스'], '출연배우': ['데이지 리들리', '아담 드라이버'], '씨네21평점': 7.0, '네티즌평점': 7.86}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d867'), '영화이름': '47미터 2', '관객수': 501595, '순위': 68, '개봉연도': '2019', '국가': '영국', '관람적절연령': '15세 관람가', '장르': '스릴러, 공포', '상영시간': '90분', '개봉날짜': '2019-08-28', '감독': ['요하네스 로버츠'], '출연배우': ['소피 넬리스', '코린 폭스'], '씨네21평점': 4.0, '네티즌평점': 4.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d868'), '영화이름': '애나벨 집으로', '관객수': 481771, '순위': 69, '개봉연도': '2019', '국가': '미국', '관람적절연령': '15세 관람가', '장르': '스릴러, 미스터리, 공포', '상영시간': '106분', '개봉날짜': '2019-06-26', '감독': ['게리 도버먼'], '출연배우': ['패트릭 윌슨', '베라 파미가'], '씨네21평점': 4.0, '네티즌평점': 5.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d869'), '영화이름': '감쪽같은 그녀', '관객수': 469425, '순위': 70, '개봉연도': '2019', '국가': '한국', '관람적절연령': '전체 관람가', '장르': '드라마', '상영시간': '104분', '개봉날짜': '2019-12-04', '감독': ['허인무'], '출연배우': ['나문희', '김수안'], '씨네21평점': 5.0, '네티즌평점': 7.33}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d86a'), '영화이름': '스파이 지니어스', '관객수': 450051, '순위': 71, '개봉연도': '2019', '국가': '미국', '관람적절연령': '전체 관람가', '장르': '어드벤처, 액션, 애니메이션', '상영시간': '102분', '개봉날짜': '2020-01-22', '감독': ['닉 브루노', '트로이 콴'], '출연배우': ['윌 스미스', '톰 홀랜드'], '씨네21평점': 6.0, '네티즌평점': 8.25}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d86b'), '영화이름': '버즈 오브 프레이(할리 퀸의 황홀한 해방)', '관객수': 394037, '순위': 72, '개봉연도': '2020', '국가': '미국', '관람적절연령': '15세 관람가', '장르': '액션, 블록버스터', '상영시간': '108분', '개봉날짜': '2020-02-05', '감독': ['캐시 얀'], '출연배우': ['마고 로비', '메리 엘리자베스 윈스티드'], '씨네21평점': 6.33, '네티즌평점': 7.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d86c'), '영화이름': '제미니 맨', '관객수': 388270, '순위': 73, '개봉연도': '2019', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '액션, 드라마, SF', '상영시간': '117분', '개봉날짜': '2019-10-09', '감독': ['이안'], '출연배우': ['윌 스미스', '메리 엘리자베스 윈스티드'], '씨네21평점': 5.0, '네티즌평점': 7.33}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d86d'), '영화이름': '고질라: 킹 오브 몬스터', '관객수': 359538, '순위': 74, '개봉연도': '2019', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '상영시간 : 132분', '상영시간': '상영시간없음', '개봉날짜': '2019-05-29', '감독': ['마이클 도허티'], '출연배우': ['밀리 바비 브라운', '베라 파미가'], '씨네21평점': 5.25, '네티즌평점': 4.4}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d86e'), '영화이름': '브링 더 소울 : 더 무비', '관객수': 336204, '순위': 75, '개봉연도': '2019', '국가': '한국', '관람적절연령': '전체 관람가', '장르': '다큐멘터리', '상영시간': '103분', '개봉날짜': '2019-08-07', '감독': ['박준수'], '출연배우': ['RM', '진'], '씨네21평점': '평점없음', '네티즌평점': '평점없음'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d86f'), '영화이름': '아담스 패밀리', '관객수': 331236, '순위': 76, '개봉연도': '2019', '국가': '캐나다,영국,미국', '관람적절연령': '전체 관람가', '장르': '코미디, 애니메이션, 가족', '상영시간': '87분', '개봉날짜': '2019-11-07', '감독': ['그래그 티어넌', '콘래드 버논'], '출연배우': ['샤를리즈 테론', '클로이 모레츠'], '씨네21평점': 6.0, '네티즌평점': 7.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d870'), '영화이름': '헬보이', '관객수': 322942, '순위': 77, '개봉연도': '2019', '국가': '미국', '관람적절연령': '청소년 관람불가', '장르': '상영시간 : 121분', '상영시간': '상영시간없음', '개봉날짜': '2019-04-10', '감독': ['닐 마샬'], '출연배우': ['데이빗 하버', '밀라 요보비치'], '씨네21평점': 5.0, '네티즌평점': 5.25}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d871'), '영화이름': '예스터데이', '관객수': 305787, '순위': 78, '개봉연도': '2019', '국가': '영국', '관람적절연령': '12세 관람가', '장르': '뮤직, 드라마', '상영시간': '116분', '개봉날짜': '2019-09-18', '감독': ['대니 보일'], '출연배우': ['히메쉬 파텔', '릴리 제임스'], '씨네21평점': 6.0, '네티즌평점': 5.6}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d872'), '영화이름': '천로역정: 천국을 찾아서', '관객수': 297104, '순위': 79, '개봉연도': '2019', '국가': '미국', '관람적절연령': '전체 관람가', '장르': '상영시간 : 113분', '상영시간': '상영시간없음', '개봉날짜': '2019-06-13', '감독': ['로버트 페르난데스'], '출연배우': ['존 라이스-데이비스', '벤 프라이스'], '씨네21평점': 5.0, '네티즌평점': '평점없음'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d873'), '영화이름': '배심원들', '관객수': 288979, '순위': 80, '개봉연도': '2018', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '드라마', '상영시간': '113분', '개봉날짜': '2019-05-15', '감독': ['홍승완'], '출연배우': ['문소리', '박형식'], '씨네21평점': 6.6, '네티즌평점': 7.2}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d874'), '영화이름': '미성년', '관객수': 288543, '순위': 81, '개봉연도': '2018', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '드라마', '상영시간': '96분', '개봉날짜': '2019-04-11', '감독': ['김윤석'], '출연배우': ['염정아', '김소진'], '씨네21평점': 7.2, '네티즌평점': 7.75}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d875'), '영화이름': '기방도령', '관객수': 287236, '순위': 82, '개봉연도': '2018', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '코미디', '상영시간': '110분', '개봉날짜': '2019-07-10', '감독': ['남대중'], '출연배우': ['준호', '정소민'], '씨네21평점': 4.67, '네티즌평점': 5.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d876'), '영화이름': '원스 어폰 어 타임... 인 할리우드', '관객수': 276569, '순위': 83, '개봉연도': '2019', '국가': '영국,미국', '관람적절연령': '청소년 관람불가', '장르': '코미디, 드라마', '상영시간': '161분', '개봉날짜': '2019-09-25', '감독': ['쿠엔틴 타란티노'], '출연배우': ['레오나르도 디카프리오', '브래드 피트'], '씨네21평점': 8.17, '네티즌평점': 8.8}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d877'), '영화이름': '라스트 크리스마스', '관객수': 250400, '순위': 84, '개봉연도': '2019', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '코미디, 멜로·로맨스', '상영시간': '103분', '개봉날짜': '2019-12-05', '감독': ['폴 페이그'], '출연배우': ['에밀리아 클라크', '헨리 골딩'], '씨네21평점': 5.5, '네티즌평점': 8.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d878'), '영화이름': '돈', '관객수': 244587, '순위': 85, '개봉연도': '2017', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '범죄', '상영시간': '115분', '개봉날짜': '2019-03-20', '감독': ['박누리'], '출연배우': ['류준열', '유지태'], '씨네21평점': 5.2, '네티즌평점': 6.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d879'), '영화이름': '명탐정 코난: 감청의 권', '관객수': 219118, '순위': 86, '개봉연도': '2019', '국가': '일본', '관람적절연령': '12세 관람가', '장르': '애니메이션', '상영시간': '109분', '개봉날짜': '2019-07-24', '감독': ['나가오카 치카'], '출연배우': ['타카야마 미나미', '야마자키 와카나'], '씨네21평점': '평점없음', '네티즌평점': '평점없음'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d87a'), '영화이름': '눈의 여왕4', '관객수': 211018, '순위': 87, '개봉연도': '2019', '국가': '러시아', '관람적절연령': '전체 관람가', '장르': '판타지, 어드벤처, 애니메이션, 가족', '상영시간': '87분', '개봉날짜': '2019-12-24', '감독': ['로버트 렌스', '알렉세이 트시칠린'], '출연배우': ['양정화', '박지윤'], '씨네21평점': 6.0, '네티즌평점': 10.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d87b'), '영화이름': '커런트 워', '관객수': 210970, '순위': 88, '개봉연도': '2018', '국가': '미국', '관람적절연령': '12세 관람가', '장르': '드라마', '상영시간': '108분', '개봉날짜': '2019-08-22', '감독': ['알폰소 고메즈-레종'], '출연배우': ['베네딕트 컴버배치', '톰 홀랜드'], '씨네21평점': 6.0, '네티즌평점': 5.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d87c'), '영화이름': '안녕, 티라노: 영원히, 함께', '관객수': 206623, '순위': 89, '개봉연도': '2018', '국가': '한국', '관람적절연령': '전체 관람가', '장르': '애니메이션', '상영시간': '98분', '개봉날짜': '2019-08-14', '감독': ['시즈노 코분'], '출연배우': ['시영준', '정혜원'], '씨네21평점': 6.0, '네티즌평점': '평점없음'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d87d'), '영화이름': '어린 의뢰인', '관객수': 204503, '순위': 90, '개봉연도': '2018', '국가': '한국', '관람적절연령': '12세 관람가', '장르': '드라마', '상영시간': '114분', '개봉날짜': '2019-05-22', '감독': ['장규성'], '출연배우': ['이동휘', '유선'], '씨네21평점': 5.33, '네티즌평점': 6.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d87e'), '영화이름': '프린스 코기', '관객수': 203742, '순위': 91, '개봉연도': '2019', '국가': '벨기에', '관람적절연령': '전체 관람가', '장르': '애니메이션', '상영시간': '82분', '개봉날짜': '2019-12-24', '감독': ['벤 스타센', '빈센트 케스텔루트'], '출연배우': ['심규혁', '김리흔'], '씨네21평점': 6.0, '네티즌평점': 10.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d87f'), '영화이름': '비스트', '관객수': 203049, '순위': 92, '개봉연도': '2018', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '스릴러, 범죄', '상영시간': '130분', '개봉날짜': '2019-06-26', '감독': ['이정호'], '출연배우': ['이성민', '유재명'], '씨네21평점': 5.0, '네티즌평점': 4.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d880'), '영화이름': '요로나의 저주', '관객수': 201686, '순위': 93, '개봉연도': '2019', '국가': '미국', '관람적절연령': '15세 관람가', '장르': '공포', '상영시간': '93분', '개봉날짜': '2019-04-17', '감독': ['마이클 차베스'], '출연배우': ['린다 카델리니', '패트리샤 벨라스케스'], '씨네21평점': 4.0, '네티즌평점': 6.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d881'), '영화이름': '롱 샷', '관객수': 191191, '순위': 94, '개봉연도': '2019', '국가': '미국', '관람적절연령': '15세 관람가', '장르': '코미디', '상영시간': '125분', '개봉날짜': '2019-07-24', '감독': ['조나단 레빈'], '출연배우': ['샤를리즈 테론', '세스 로건'], '씨네21평점': 5.5, '네티즌평점': 6.5}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d882'), '영화이름': '앵그리 버드 2: 독수리 왕국의 침공', '관객수': 188875, '순위': 95, '개봉연도': '2019', '국가': '미국', '관람적절연령': '전체 관람가', '장르': '액션, 애니메이션', '상영시간': '96분', '개봉날짜': '2019-08-07', '감독': ['서럽 밴 오먼'], '출연배우': ['제이슨 서디키스', '조시 게드'], '씨네21평점': 6.0, '네티즌평점': '평점없음'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d883'), '영화이름': '엔젤 해즈 폴른', '관객수': 181416, '순위': 96, '개봉연도': '2019', '국가': '미국', '관람적절연령': '15세 관람가', '장르': '액션, 스릴러', '상영시간': '121분', '개봉날짜': '2019-11-13', '감독': ['릭 로만 워'], '출연배우': ['제라드 버틀러', '모건 프리먼'], '씨네21평점': 5.0, '네티즌평점': 7.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d884'), '영화이름': '두번할까요', '관객수': 178218, '순위': 97, '개봉연도': '2018', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '코미디, 멜로·로맨스', '상영시간': '112분', '개봉날짜': '2019-10-17', '감독': ['박용집'], '출연배우': ['권상우', '이정현'], '씨네21평점': 3.5, '네티즌평점': 6.33}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d885'), '영화이름': '진범', '관객수': 168126, '순위': 98, '개봉연도': '2018', '국가': '한국', '관람적절연령': '15세 관람가', '장르': '스릴러', '상영시간': '100분', '개봉날짜': '2019-07-10', '감독': ['고정욱'], '출연배우': ['송새벽', '유선'], '씨네21평점': 6.5, '네티즌평점': 7.0}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d886'), '영화이름': '이웃집 토토로', '관객수': 163083, '순위': 99, '개봉연도': '1988', '국가': '일본', '관람적절연령': '전체 관람가', '장르': '판타지, 애니메이션, 드라마', '상영시간': '88분', '개봉날짜': '2019-06-06', '감독': ['미야자키 하야오'], '출연배우': ['히다카 노리코', '사카모토 치카'], '씨네21평점': 8.85, '네티즌평점': '평점없음'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d887'), '영화이름': '타오르는 여인의 초상', '관객수': 146246, '순위': 100, '개봉연도': '2019', '국가': '프랑스', '관람적절연령': '15세 관람가', '장르': '드라마', '상영시간': '120분', '개봉날짜': '2020-01-16', '감독': ['셀린 시아마'], '출연배우': ['아델 에넬', '노에미 멜랑'], '씨네21평점': 9.5, '네티즌평점': 9.2}

# %% [markdown]
# ## SQL 쿼리를 통한 데이터 조회

# %%
# 특정 key값(MySQL로 치면 Schema 이름) 수정
movie_info.update_many({},{'$rename':{'개봉연도':'개봉년도'}})

# %%
docs = movie_info.find({}).limit(5)
for doc in docs:
    print(doc)
# Out:
# {'_id': ObjectId('5e8ecdf10287aaf25b95d824'), '영화이름': '어벤져스: 엔드게임', '관객수': 13779286, '순위': 1, '국가': '미국', '관람적절연령': '12세 관람가', '장르': '액션, SF', '상영시간': '181분', '개봉날짜': '2019-04-24', '감독': ['안소니 루소', '조 루소'], '출연배우': ['로버트 다우니 주니어', '크리스 에반스'], '씨네21평점': 7.17, '네티즌평점': 8.5, '개봉년도': '2019'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d825'), '영화이름': '겨울왕국 2', '관객수': 13748486, '순위': 2, '국가': '미국', '관람적절연령': '전체 관람가', '장르': '판타지, 코미디, 어드벤처, 애니메이션, 뮤지컬, 가족', '상영시간': '103분', '개봉날짜': '2019-11-21', '감독': ['크리스 벅', '제니퍼 리'], '출연배우': ['크리스틴 벨', '이디나 멘젤'], '씨네21평점': 6.25, '네티즌평점': 8.67, '개봉년도': '2019'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d826'), '영화이름': '알라딘', '관객수': 12557831, '순위': 3, '국가': '미국', '관람적절연령': '전체 관람가', '장르': '상영시간 : 128분', '상영시간': '상영시간없음', '개봉날짜': '2019-05-23', '감독': ['가이 리치'], '출연배우': ['메나 마수드', '윌 스미스'], '씨네21평점': 5.8, '네티즌평점': 8.43, '개봉년도': '2019'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d827'), '영화이름': '기생충', '관객수': 10289709, '순위': 4, '국가': '한국', '관람적절연령': '15세 관람가', '장르': '드라마', '상영시간': '131분', '개봉날짜': '2019-05-30', '감독': ['봉준호'], '출연배우': ['송강호', '이선균'], '씨네21평점': 9.09, '네티즌평점': 9.14, '개봉년도': '2019'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d828'), '영화이름': '엑시트', '관객수': 9437454, '순위': 5, '국가': '한국', '관람적절연령': '12세 관람가', '장르': '코미디, 액션', '상영시간': '103분', '개봉날짜': '2019-07-31', '감독': ['이상근'], '출연배우': ['조정석', '임윤아'], '씨네21평점': 7.17, '네티즌평점': 8.2, '개봉년도': '2019'}

# %%
docs = movie_info.find({}).sort("네티즌평점").limit(10)
for doc in docs:
    print(doc)
# Out:
# {'_id': ObjectId('5e8ecdf10287aaf25b95d87f'), '영화이름': '비스트', '관객수': 203049, '순위': 92, '국가': '한국', '관람적절연령': '15세 관람가', '장르': '스릴러, 범죄', '상영시간': '130분', '개봉날짜': '2019-06-26', '감독': ['이정호'], '출연배우': ['이성민', '유재명'], '씨네21평점': 5.0, '네티즌평점': 4.0, '개봉년도': '2018'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d840'), '영화이름': '정직한 후보', '관객수': 1527775, '순위': 29, '국가': '한국', '관람적절연령': '12세 관람가', '장르': '코미디', '상영시간': '105분', '개봉날짜': '2020-02-12', '감독': ['장유정'], '출연배우': ['라미란', '김무열'], '씨네21평점': 5.0, '네티즌평점': 4.2, '개봉년도': '2019'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d86d'), '영화이름': '고질라: 킹 오브 몬스터', '관객수': 359538, '순위': 74, '국가': '미국', '관람적절연령': '12세 관람가', '장르': '상영시간 : 132분', '상영시간': '상영시간없음', '개봉날짜': '2019-05-29', '감독': ['마이클 도허티'], '출연배우': ['밀리 바비 브라운', '베라 파미가'], '씨네21평점': 5.25, '네티즌평점': 4.4, '개봉년도': '2019'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d83c'), '영화이름': '변신', '관객수': 1805622, '순위': 25, '국가': '한국', '관람적절연령': '15세 관람가', '장르': '스릴러, 공포', '상영시간': '113분', '개봉날짜': '2019-08-21', '감독': ['김홍선'], '출연배우': ['배성우', '성동일'], '씨네21평점': 4.33, '네티즌평점': 4.5, '개봉년도': '2018'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d867'), '영화이름': '47미터 2', '관객수': 501595, '순위': 68, '국가': '영국', '관람적절연령': '15세 관람가', '장르': '스릴러, 공포', '상영시간': '90분', '개봉날짜': '2019-08-28', '감독': ['요하네스 로버츠'], '출연배우': ['소피 넬리스', '코린 폭스'], '씨네21평점': 4.0, '네티즌평점': 4.5, '개봉년도': '2019'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d864'), '영화이름': '양자물리학', '관객수': 544988, '순위': 65, '국가': '한국', '관람적절연령': '15세 관람가', '장르': '범죄', '상영시간': '119분', '개봉날짜': '2019-09-25', '감독': ['이성태'], '출연배우': ['박해수', '서예지'], '씨네21평점': 4.5, '네티즌평점': 4.8, '개봉년도': '2019'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d83d'), '영화이름': '걸캅스', '관객수': 1629777, '순위': 26, '국가': '한국', '관람적절연령': '15세 관람가', '장르': '코미디, 액션', '상영시간': '107분', '개봉날짜': '2019-05-09', '감독': ['정다원'], '출연배우': ['라미란', '이성경'], '씨네21평점': 5.0, '네티즌평점': 4.83, '개봉년도': '2018'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d84b'), '영화이름': '롱 리브 더 킹: 목포 영웅', '관객수': 1094768, '순위': 40, '국가': '한국', '관람적절연령': '15세 관람가', '장르': '액션, 드라마', '상영시간': '118분', '개봉날짜': '2019-06-19', '감독': ['강윤성'], '출연배우': ['김래원', '원진아'], '씨네21평점': 4.67, '네티즌평점': 5.0, '개봉년도': '2018'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d85f'), '영화이름': '미스터 주: 사라진 VIP', '관객수': 602401, '순위': 60, '국가': '한국', '관람적절연령': '12세 관람가', '장르': '코미디, 드라마', '상영시간': '113분', '개봉날짜': '2020-01-22', '감독': ['김태윤'], '출연배우': ['이성민', '김서형'], '씨네21평점': 4.5, '네티즌평점': 5.0, '개봉년도': '2019'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d868'), '영화이름': '애나벨 집으로', '관객수': 481771, '순위': 69, '국가': '미국', '관람적절연령': '15세 관람가', '장르': '스릴러, 미스터리, 공포', '상영시간': '106분', '개봉날짜': '2019-06-26', '감독': ['게리 도버먼'], '출연배우': ['패트릭 윌슨', '베라 파미가'], '씨네21평점': 4.0, '네티즌평점': 5.0, '개봉년도': '2019'}

# %%
docs = movie_info.find({'개봉년도':{'$exists':True}}).sort('순위').limit(3)
for doc in docs:
    print(doc)
# Out:
# {'_id': ObjectId('5e8ecdf10287aaf25b95d824'), '영화이름': '어벤져스: 엔드게임', '관객수': 13779286, '순위': 1, '국가': '미국', '관람적절연령': '12세 관람가', '장르': '액션, SF', '상영시간': '181분', '개봉날짜': '2019-04-24', '감독': ['안소니 루소', '조 루소'], '출연배우': ['로버트 다우니 주니어', '크리스 에반스'], '씨네21평점': 7.17, '네티즌평점': 8.5, '개봉년도': '2019'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d825'), '영화이름': '겨울왕국 2', '관객수': 13748486, '순위': 2, '국가': '미국', '관람적절연령': '전체 관람가', '장르': '판타지, 코미디, 어드벤처, 애니메이션, 뮤지컬, 가족', '상영시간': '103분', '개봉날짜': '2019-11-21', '감독': ['크리스 벅', '제니퍼 리'], '출연배우': ['크리스틴 벨', '이디나 멘젤'], '씨네21평점': 6.25, '네티즌평점': 8.67, '개봉년도': '2019'}
# {'_id': ObjectId('5e8ecdf10287aaf25b95d826'), '영화이름': '알라딘', '관객수': 12557831, '순위': 3, '국가': '미국', '관람적절연령': '전체 관람가', '장르': '상영시간 : 128분', '상영시간': '상영시간없음', '개봉날짜': '2019-05-23', '감독': ['가이 리치'], '출연배우': ['메나 마수드', '윌 스미스'], '씨네21평점': 5.8, '네티즌평점': 8.43, '개봉년도': '2019'}

# %%
docs = movie_info.find({'네티즌평점':{'$exists':True}}, {'_id':0, '영화이름':1,'관객수':1,'장르':1}).limit(3)
for doc in docs:
    print(doc)
# Out:
# {'영화이름': '어벤져스: 엔드게임', '관객수': 13779286, '장르': '액션, SF'}
# {'영화이름': '겨울왕국 2', '관객수': 13748486, '장르': '판타지, 코미디, 어드벤처, 애니메이션, 뮤지컬, 가족'}
# {'영화이름': '알라딘', '관객수': 12557831, '장르': '상영시간 : 128분'}
